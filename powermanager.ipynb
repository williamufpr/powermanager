# %%
from IPython.display import display, Markdown

display(Markdown("""
<div style="background-color:#f0f8ff; padding:20px;">
    <h1 style="color:#0074D9;">Projeto de Análise de Consumo - Equipamentos DELL POWER EDGE</h1>
    <p style="color:#0074D9;">
        Este projeto visa analisar o consumo energético de uma série de equipamentos DELL POWER EDGE, aplicando algoritmos de clusterização para classificar os equipamentos em três categorias: baixo, médio e alto consumo.
    </p>
</div>
"""))
# Out:
# <div style="background-color:#f0f8ff; padding:20px;">
#     <h1 style="color:#0074D9;">Projeto de Análise de Consumo - Equipamentos DELL POWER EDGE</h1>
#     <p style="color:#0074D9;">
#         Este projeto visa analisar o consumo energético de uma série de equipamentos DELL POWER EDGE, aplicando algoritmos de clusterização para classificar os equipamentos em três categorias: baixo, médio e alto consumo.
#     </p>
# </div>

# %%
import os

print("Diretório atual:", os.getcwd())
print("Existe src/gemini?", os.path.exists("./src/gemini"))

# os.chdir("./src/gemini")

from src.gemini.gemini_structure import verificar_estrutura_df
nome_arquivo = './data/dataset.csv'  # Substitua pelo caminho do seu arquivo CSV
df_carregado = verificar_estrutura_df(nome_arquivo)
# Out:
# Diretório atual: /Users/william/minilab/powermanager
# Existe src/gemini? True
# DataFrame './data/dataset.csv' carregado com sucesso!
#
# --- Informações Iniciais do DataFrame ---
#
# Primeiras 5 linhas:
#                            potmin_SMV340200  ...  tempmax_idrac-FDQGPV3
# Date and time                                ...
# 2025-06-10 16:15:00-03:00             714.0  ...                   27.0
# 2025-06-10 16:30:00-03:00             729.0  ...                   27.0
# 2025-06-10 16:45:00-03:00             711.0  ...                   27.0
# 2025-06-10 17:00:00-03:00             720.0  ...                   27.0
# 2025-06-10 17:15:00-03:00             722.0  ...                   27.0
#
# [5 rows x 125 columns]
#
# Últimas 5 linhas:
#                            potmin_SMV340200  ...  tempmax_idrac-FDQGPV3
# Date and time                                ...
# 2025-06-17 15:00:00-03:00             707.0  ...                   27.0
# ...
